# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
# %matplotlib inline

# %%
df=pd.read_csv('CarPrice_Assignment.csv')

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.corr()
# Out:
# C:\Users\jaxon\AppData\Local\Temp\ipykernel_22716\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# peakrpm          -0.203789   0.273606  -0.360469  -0.287242 -0.220012
# citympg           0.015940  -0.035823  -0.470414  -0.670909 -0.642704
# highwaympg        0.011255   0.034606  -0.544082  -0.704662 -0.677218
# price            -0.109093  -0.079978   0.577816   0.682920  0.759325
#
#                   carheight  curbweight  enginesize  boreratio    stroke  \
# car_ID             0.255960    0.071962   -0.033930   0.260064 -0.160824
# symboling         -0.541038   -0.227691   -0.105790  -0.130051 -0.008735
# wheelbase          0.589435    0.776386    0.569329   0.488750  0.160959
# carlength          0.491029    0.877728    0.683360   0.606454  0.129533
# carwidth           0.279210    0.867032    0.735433   0.559150  0.182942
# carheight          1.000000    0.295572    0.067149   0.171071 -0.055307
# curbweight         0.295572    1.000000    0.850594   0.648480  0.168790
# enginesize         0.067149    0.850594    1.000000   0.583774  0.203129
# boreratio          0.171071    0.648480    0.583774   1.000000 -0.055909
# stroke            -0.055307    0.168790    0.203129  -0.055909  1.000000
# compressionratio   0.261214    0.151362    0.028971   0.005197  0.186110
# horsepower        -0.108802    0.750739    0.809769   0.573677  0.080940
# peakrpm           -0.320411   -0.266243   -0.244660  -0.254976 -0.067964
# citympg           -0.048640   -0.757414   -0.653658  -0.584532 -0.042145
# highwaympg        -0.107358   -0.797465   -0.677470  -0.587012 -0.043931
# price              0.119336    0.835305    0.874145   0.553173  0.079443
#
#                   compressionratio  horsepower   peakrpm   citympg  \
# car_ID                    0.150276   -0.015006 -0.203789  0.015940
# symboling                -0.178515    0.070873  0.273606 -0.035823
# wheelbase                 0.249786    0.353294 -0.360469 -0.470414
# carlength                 0.158414    0.552623 -0.287242 -0.670909
# carwidth                  0.181129    0.640732 -0.220012 -0.642704
# carheight                 0.261214   -0.108802 -0.320411 -0.048640
# curbweight                0.151362    0.750739 -0.266243 -0.757414
# enginesize                0.028971    0.809769 -0.244660 -0.653658
# boreratio                 0.005197    0.573677 -0.254976 -0.584532
# stroke                    0.186110    0.080940 -0.067964 -0.042145
# compressionratio          1.000000   -0.204326 -0.435741  0.324701
# horsepower               -0.204326    1.000000  0.131073 -0.801456
# peakrpm                  -0.435741    0.131073  1.000000 -0.113544
# citympg                   0.324701   -0.801456 -0.113544  1.000000
# highwaympg                0.265201   -0.770544 -0.054275  0.971337
# price                     0.067984    0.808139 -0.085267 -0.685751
#
#                   highwaympg     price
# car_ID              0.011255 -0.109093
# symboling           0.034606 -0.079978
# wheelbase          -0.544082  0.577816
# carlength          -0.704662  0.682920
# carwidth           -0.677218  0.759325
# carheight          -0.107358  0.119336
# curbweight         -0.797465  0.835305
# enginesize         -0.677470  0.874145
# boreratio          -0.587012  0.553173
# stroke             -0.043931  0.079443
# compressionratio    0.265201  0.067984
# horsepower         -0.770544  0.808139
# peakrpm            -0.054275 -0.085267
# citympg             0.971337 -0.685751
# highwaympg          1.000000 -0.697599
# price              -0.697599  1.000000

# %%
sns.set(rc={"figure.figsize":(20, 20)})
sns.heatmap(df.corr(), annot = True)
# Out:
# C:\Users\jaxon\AppData\Local\Temp\ipykernel_22716\1194010974.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True)
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
df.drop(['car_ID'], axis = 1, inplace = True)

# %%
#Visualize some relationships
for col in df.columns: 
    if df[col].dtypes != 'object':
        sns.lmplot(data = df, x = col, y = 'price')

# %%
#To drop because uncorrelated to price: 
to_drop = ['peakrpm', 'compressionratio', 'stroke', 'symboling']
df.drop(df[to_drop], axis = 1, inplace = True)

# %%
categorical = []
numerical = []
for col in df.columns: 
    if df[col].dtypes == 'object':
        categorical.append(col)
    else: 
        numerical.append(col)

# %%
categorical
# Out:
# ['CarName',
#  'fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem']

# %%
df.columns
# Out:
# Index(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
#        'fuelsystem', 'boreratio', 'horsepower', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df['CarName'] = df['CarName'].apply(lambda x: x.split()[0])
df.head()
# Out:
#        CarName fueltype aspiration doornumber      carbody drivewheel  \
# 0  alfa-romero      gas        std        two  convertible        rwd
# 1  alfa-romero      gas        std        two  convertible        rwd
# 2  alfa-romero      gas        std        two    hatchback        rwd
# 3         audi      gas        std       four        sedan        fwd
# 4         audi      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  ...  curbweight  enginetype  \
# 0          front       88.6      168.8      64.1  ...        2548        dohc
# 1          front       88.6      168.8      64.1  ...        2548        dohc
# 2          front       94.5      171.2      65.5  ...        2823        ohcv
# 3          front       99.8      176.6      66.2  ...        2337         ohc
# 4          front       99.4      176.6      66.4  ...        2824         ohc
#
#   cylindernumber enginesize  fuelsystem boreratio  horsepower  citympg  \
# 0           four        130        mpfi      3.47         111       21
# 1           four        130        mpfi      3.47         111       21
# 2            six        152        mpfi      2.68         154       19
# 3           four        109        mpfi      3.19         102       24
# 4           five        136        mpfi      3.19         115       18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 21 columns]

# %%
sns.set(rc={'figure.figsize':(30,10)})
sns.countplot(data = df, x='CarName')
# Out:
# <Axes: xlabel='CarName', ylabel='count'>

# %%
df['CarName'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
df['CarName'] = df['CarName'].str.lower()
df['CarName'] = df['CarName'].replace({'vw':'volkswagen','vokswagen':'volkswagen','toyouta':'toyota','maxda':'mazda','porcshce':'porsche'})

# %%
sns.countplot(data = df, x='CarName')
# Out:
# <Axes: xlabel='CarName', ylabel='count'>

# %%
#Create dummies, and numerical features
x1 = pd.get_dummies(df[categorical], drop_first = False)
x2 = df[numerical]
X = pd.concat([x2,x1], axis = 1)
X.drop('price', axis = 1, inplace = True)
X.to_csv('dummy_df')
cols_to_use = X.columns
X.to_csv('cols_to_use')
X = X.values

# %%
y = df['price']
sns.histplot(data=df, x="price", kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
#Skewed distribution
y=np.log(y)
y=y.values

# %%
sns.histplot(data=df, x=y, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
#Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.333, random_state=1)

#Scale
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
print(len(x1.columns))
X_train[:, :(len(x1.columns))]= sc.fit_transform(X_train[:, :(len(x1.columns))])
X_test[:, :(len(x1.columns))]= sc.transform(X_test[:, :(len(x1.columns))])
len(X_train[0])
# Out:
# 60
# 70

# %%
#Importing regressors
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

#Regression Models
from sklearn.linear_model import LinearRegression, Lasso, Ridge, RidgeCV
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
import xgboost as xgb
from lightgbm import LGBMRegressor
# Out:
# Collecting xgboost
#   Downloading xgboost-1.5.2.tar.gz (730 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\jaxon\appdata\local\programs\python\python36-32\lib\site-packages (from xgboost) (1.19.5)
# Requirement already satisfied: scipy in c:\users\jaxon\appdata\local\programs\python\python36-32\lib\site-packages (from xgboost) (1.5.4)
# Using legacy 'setup.py install' for xgboost, since package 'wheel' is not installed.
# Installing collected packages: xgboost
#     Running setup.py install for xgboost: started
#     Running setup.py install for xgboost: finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\jaxon\appdata\local\programs\python\python36-32\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jaxon\\AppData\\Local\\Temp\\pip-install-yuncal1r\\xgboost_b01f77f0d38a450da1c0db361f4f4dbd\\setup.py'"'"'; __file__='"'"'C:\\Users\\jaxon\\AppData\\Local\\Temp\\pip-install-yuncal1r\\xgboost_b01f77f0d38a450da1c0db361f4f4dbd\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\jaxon\AppData\Local\Temp\pip-record-zk479j1o\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\users\jaxon\appdata\local\programs\python\python36-32\Include\xgboost'
#          cwd: C:\Users\jaxon\AppData\Local\Temp\pip-install-yuncal1r\xgboost_b01f77f0d38a450da1c0db361f4f4dbd\
#     Complete output (807 lines):
#     c:\users\jaxon\appdata\local\programs\python\python36-32\lib\distutils\dist.py:261: UserWarning: Unknown distribution option: 'long_description_content_type'
#       warnings.warn(msg)
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib.win32-3.6
#     creating build\lib.win32-3.6\xgboost
#     copying xgboost\callback.py -> build\lib.win32-3.6\xgboost
#     copying xgboost\compat.py -> build\lib.win32-3.6\xgboost
#     copying xgboost\config.py -> build\lib.win32-3.6\xgboost
#     copying xgboost\core.py -> build\lib.win32-3.6\xgboost
#     copying xgboost\dask.py -> build\lib.win32-3.6\xgboost
#     copying xgboost\data.py -> build\lib.win32-3.6\xgboost
#     copying xgboost\libpath.py -> build\lib.win32-3.6\xgboost
#     copying xgboost\plotting.py -> build\lib.win32-3.6\xgboost
#     copying xgboost\rabit.py -> build\lib.win32-3.6\xgboost
#     copying xgboost\sklearn.py -> build\lib.win32-3.6\xgboost
#     copying xgboost\tracker.py -> build\lib.win32-3.6\xgboost
#     copying xgboost\training.py -> build\lib.win32-3.6\xgboost
#     copying xgboost\__init__.py -> build\lib.win32-3.6\xgboost
#     running egg_info
#     writing xgboost.egg-info\PKG-INFO
#     writing dependency_links to xgboost.egg-info\dependency_links.txt
#     writing requirements to xgboost.egg-info\requires.txt
#     writing top-level names to xgboost.egg-info\top_level.txt
#     reading manifest file 'xgboost.egg-info\SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no previously-included files found matching 'xgboost\cmake\RPackageInstall.cmake.in'
#     warning: no previously-included files found matching 'xgboost\cmake\RPackageInstallTargetSetup.cmake'
#     warning: no previously-included files found matching 'xgboost\cmake\Sanitizer.cmake'
#     warning: no previously-included files found matching 'xgboost\cmake\modules\FindASan.cmake'
#     warning: no previously-included files found matching 'xgboost\cmake\modules\FindLSan.cmake'
#     warning: no previously-included files found matching 'xgboost\cmake\modules\FindLibR.cmake'
#     warning: no previously-included files found matching 'xgboost\cmake\modules\FindTSan.cmake'
#     warning: no previously-included files found matching 'xgboost\cmake\modules\FindUBSan.cmake'
#     no previously-included directories found matching 'xgboost\rabit\doc'
#     no previously-included directories found matching 'xgboost\rabit\guide'
#     warning: no previously-included files found matching 'xgboost\dmlc-core\cmake\gtest_cmake.in'
#     warning: no previously-included files found matching 'xgboost\dmlc-core\cmake\lint.cmake'
#     warning: no previously-included files found matching 'xgboost\dmlc-core\cmake\Sanitizer.cmake'
#     warning: no previously-included files found matching 'xgboost\dmlc-core\cmake\Modules\FindASan.cmake'
#     warning: no previously-included files found matching 'xgboost\dmlc-core\cmake\Modules\FindLSan.cmake'
#     warning: no previously-included files found matching 'xgboost\dmlc-core\cmake\Modules\FindTSan.cmake'
#     warning: no previously-included files found matching 'xgboost\dmlc-core\cmake\Modules\FindUBSan.cmake'
#     no previously-included directories found matching 'xgboost\dmlc-core\doc'
#     warning: manifest_maker: MANIFEST.in, line 52: path 'xgboost/dmlc-core/scripts/' cannot end with '/'
#
#     warning: no previously-included files matching '*.py[oc]' found anywhere in distribution
#     writing manifest file 'xgboost.egg-info\SOURCES.txt'
#     copying xgboost\CMakeLists.txt -> build\lib.win32-3.6\xgboost
#     copying xgboost\LICENSE -> build\lib.win32-3.6\xgboost
#     copying xgboost\VERSION -> build\lib.win32-3.6\xgboost
#     copying xgboost\py.typed -> build\lib.win32-3.6\xgboost
#     creating build\lib.win32-3.6\xgboost\cmake
#     copying xgboost\cmake\Doc.cmake -> build\lib.win32-3.6\xgboost\cmake
#     copying xgboost\cmake\FindPrefetchIntrinsics.cmake -> build\lib.win32-3.6\xgboost\cmake
#     copying xgboost\cmake\Python_version.in -> build\lib.win32-3.6\xgboost\cmake
#     copying xgboost\cmake\Utils.cmake -> build\lib.win32-3.6\xgboost\cmake
#     copying xgboost\cmake\Version.cmake -> build\lib.win32-3.6\xgboost\cmake
#     copying xgboost\cmake\version_config.h.in -> build\lib.win32-3.6\xgboost\cmake
#     copying xgboost\cmake\xgboost-config.cmake.in -> build\lib.win32-3.6\xgboost\cmake
#     copying xgboost\cmake\xgboost.pc.in -> build\lib.win32-3.6\xgboost\cmake
#     creating build\lib.win32-3.6\xgboost\cmake\modules
#     copying xgboost\cmake\modules\FindNVML.cmake -> build\lib.win32-3.6\xgboost\cmake\modules
#     copying xgboost\cmake\modules\FindNVTX.cmake -> build\lib.win32-3.6\xgboost\cmake\modules
#     copying xgboost\cmake\modules\FindNccl.cmake -> build\lib.win32-3.6\xgboost\cmake\modules
#     creating build\lib.win32-3.6\xgboost\dmlc-core
#     copying xgboost\dmlc-core\CMakeLists.txt -> build\lib.win32-3.6\xgboost\dmlc-core
#     creating build\lib.win32-3.6\xgboost\dmlc-core\cmake
#     copying xgboost\dmlc-core\cmake\Utils.cmake -> build\lib.win32-3.6\xgboost\dmlc-core\cmake
#     copying xgboost\dmlc-core\cmake\build_config.h.in -> build\lib.win32-3.6\xgboost\dmlc-core\cmake
#     copying xgboost\dmlc-core\cmake\dmlc-config.cmake.in -> build\lib.win32-3.6\xgboost\dmlc-core\cmake
#     creating build\lib.win32-3.6\xgboost\dmlc-core\cmake\Modules
#     copying xgboost\dmlc-core\cmake\Modules\FindHDFS.cmake -> build\lib.win32-3.6\xgboost\dmlc-core\cmake\Modules
#     creating build\lib.win32-3.6\xgboost\dmlc-core\include
#     creating build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\any.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\array_view.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\base.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\blockingconcurrentqueue.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\build_config_default.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\common.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\concurrency.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\concurrentqueue.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\config.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\data.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\endian.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\filesystem.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\input_split_shuffle.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\io.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\json.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\logging.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\lua.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\memory.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\memory_io.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\omp.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\optional.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\parameter.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\recordio.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\registry.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\serializer.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\strtonum.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\thread_group.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\thread_local.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\threadediter.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\timer.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\type_traits.h -> build\lib.win32-3.6\xgboost\dmlc-core\include\dmlc
#     creating build\lib.win32-3.6\xgboost\dmlc-core\make
#     copying xgboost\dmlc-core\make\config.mk -> build\lib.win32-3.6\xgboost\dmlc-core\make
#     copying xgboost\dmlc-core\make\dmlc.mk -> build\lib.win32-3.6\xgboost\dmlc-core\make
#     creating build\lib.win32-3.6\xgboost\dmlc-core\src
#     copying xgboost\dmlc-core\src\config.cc -> build\lib.win32-3.6\xgboost\dmlc-core\src
#     copying xgboost\dmlc-core\src\data.cc -> build\lib.win32-3.6\xgboost\dmlc-core\src
#     copying xgboost\dmlc-core\src\io.cc -> build\lib.win32-3.6\xgboost\dmlc-core\src
#     copying xgboost\dmlc-core\src\recordio.cc -> build\lib.win32-3.6\xgboost\dmlc-core\src
#     creating build\lib.win32-3.6\xgboost\dmlc-core\src\data
#     copying xgboost\dmlc-core\src\data\basic_row_iter.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\data
#     copying xgboost\dmlc-core\src\data\csv_parser.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\data
#     copying xgboost\dmlc-core\src\data\disk_row_iter.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\data
#     copying xgboost\dmlc-core\src\data\libfm_parser.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\data
#     copying xgboost\dmlc-core\src\data\libsvm_parser.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\data
#     copying xgboost\dmlc-core\src\data\parser.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\data
#     copying xgboost\dmlc-core\src\data\row_block.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\data
#     copying xgboost\dmlc-core\src\data\text_parser.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\data
#     creating build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\azure_filesys.cc -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\azure_filesys.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\cached_input_split.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\filesys.cc -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\hdfs_filesys.cc -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\hdfs_filesys.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\indexed_recordio_split.cc -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\indexed_recordio_split.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\input_split_base.cc -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\input_split_base.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\line_split.cc -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\line_split.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\local_filesys.cc -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\local_filesys.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\recordio_split.cc -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\recordio_split.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\s3_filesys.cc -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\s3_filesys.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\single_file_split.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\single_threaded_input_split.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\threaded_input_split.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\uri_spec.h -> build\lib.win32-3.6\xgboost\dmlc-core\src\io
#     creating build\lib.win32-3.6\xgboost\dmlc-core\tracker
#     copying xgboost\dmlc-core\tracker\dmlc-submit -> build\lib.win32-3.6\xgboost\dmlc-core\tracker
#     creating build\lib.win32-3.6\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\__init__.py -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\kubernetes.py -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\launcher.py -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\local.py -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\mesos.py -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\mpi.py -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\opts.py -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\sge.py -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\slurm.py -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\ssh.py -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\submit.py -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\tracker.py -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\util.py -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\yarn.py -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\dmlc_tracker
#     creating build\lib.win32-3.6\xgboost\dmlc-core\tracker\yarn
#     copying xgboost\dmlc-core\tracker\yarn\build.bat -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\yarn
#     copying xgboost\dmlc-core\tracker\yarn\build.sh -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\yarn
#     copying xgboost\dmlc-core\tracker\yarn\pom.xml -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\yarn
#     creating build\lib.win32-3.6\xgboost\dmlc-core\tracker\yarn\src
#     creating build\lib.win32-3.6\xgboost\dmlc-core\tracker\yarn\src\main
#     creating build\lib.win32-3.6\xgboost\dmlc-core\tracker\yarn\src\main\java
#     creating build\lib.win32-3.6\xgboost\dmlc-core\tracker\yarn\src\main\java\org
#     creating build\lib.win32-3.6\xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache
#     creating build\lib.win32-3.6\xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop
#     creating build\lib.win32-3.6\xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop\yarn
#     creating build\lib.win32-3.6\xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop\yarn\dmlc
#     copying xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop\yarn\dmlc\ApplicationMaster.java -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop\yarn\dmlc
#     copying xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop\yarn\dmlc\Client.java -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop\yarn\dmlc
#     copying xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop\yarn\dmlc\TaskRecord.java -> build\lib.win32-3.6\xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop\yarn\dmlc
#     creating build\lib.win32-3.6\xgboost\dmlc-core\windows
#     copying xgboost\dmlc-core\windows\dmlc.sln -> build\lib.win32-3.6\xgboost\dmlc-core\windows
#     creating build\lib.win32-3.6\xgboost\dmlc-core\windows\dmlc
#     copying xgboost\dmlc-core\windows\dmlc\dmlc.vcxproj -> build\lib.win32-3.6\xgboost\dmlc-core\windows\dmlc
#     creating build\lib.win32-3.6\xgboost\include
#     creating build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\base.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\c_api.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\data.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\feature_map.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\gbm.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\generic_parameters.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\global_config.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\host_device_vector.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\intrusive_ptr.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\json.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\json_io.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\learner.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\linalg.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\linear_updater.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\logging.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\metric.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\model.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\objective.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\parameter.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\predictor.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\span.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\tree_model.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\tree_updater.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     copying xgboost\include\xgboost\version_config.h -> build\lib.win32-3.6\xgboost\include\xgboost
#     creating build\lib.win32-3.6\xgboost\plugin
#     copying xgboost\plugin\CMakeLists.txt -> build\lib.win32-3.6\xgboost\plugin
#     copying xgboost\plugin\README.md -> build\lib.win32-3.6\xgboost\plugin
#     creating build\lib.win32-3.6\xgboost\plugin\dense_parser
#     copying xgboost\plugin\dense_parser\dense_libsvm.cc -> build\lib.win32-3.6\xgboost\plugin\dense_parser
#     creating build\lib.win32-3.6\xgboost\plugin\example
#     copying xgboost\plugin\example\README.md -> build\lib.win32-3.6\xgboost\plugin\example
#     copying xgboost\plugin\example\custom_obj.cc -> build\lib.win32-3.6\xgboost\plugin\example
#     creating build\lib.win32-3.6\xgboost\plugin\updater_gpu
#     copying xgboost\plugin\updater_gpu\README.md -> build\lib.win32-3.6\xgboost\plugin\updater_gpu
#     creating build\lib.win32-3.6\xgboost\plugin\updater_oneapi
#     copying xgboost\plugin\updater_oneapi\README.md -> build\lib.win32-3.6\xgboost\plugin\updater_oneapi
#     copying xgboost\plugin\updater_oneapi\predictor_oneapi.cc -> build\lib.win32-3.6\xgboost\plugin\updater_oneapi
#     copying xgboost\plugin\updater_oneapi\regression_loss_oneapi.h -> build\lib.win32-3.6\xgboost\plugin\updater_oneapi
#     copying xgboost\plugin\updater_oneapi\regression_obj_oneapi.cc -> build\lib.win32-3.6\xgboost\plugin\updater_oneapi
#     creating build\lib.win32-3.6\xgboost\rabit
#     copying xgboost\rabit\CMakeLists.txt -> build\lib.win32-3.6\xgboost\rabit
#     creating build\lib.win32-3.6\xgboost\rabit\include
#     creating build\lib.win32-3.6\xgboost\rabit\include\rabit
#     copying xgboost\rabit\include\rabit\base.h -> build\lib.win32-3.6\xgboost\rabit\include\rabit
#     copying xgboost\rabit\include\rabit\c_api.h -> build\lib.win32-3.6\xgboost\rabit\include\rabit
#     copying xgboost\rabit\include\rabit\rabit.h -> build\lib.win32-3.6\xgboost\rabit\include\rabit
#     copying xgboost\rabit\include\rabit\serializable.h -> build\lib.win32-3.6\xgboost\rabit\include\rabit
#     creating build\lib.win32-3.6\xgboost\rabit\include\rabit\internal
#     copying xgboost\rabit\include\rabit\internal\engine.h -> build\lib.win32-3.6\xgboost\rabit\include\rabit\internal
#     copying xgboost\rabit\include\rabit\internal\io.h -> build\lib.win32-3.6\xgboost\rabit\include\rabit\internal
#     copying xgboost\rabit\include\rabit\internal\rabit-inl.h -> build\lib.win32-3.6\xgboost\rabit\include\rabit\internal
#     copying xgboost\rabit\include\rabit\internal\socket.h -> build\lib.win32-3.6\xgboost\rabit\include\rabit\internal
#     copying xgboost\rabit\include\rabit\internal\utils.h -> build\lib.win32-3.6\xgboost\rabit\include\rabit\internal
#     creating build\lib.win32-3.6\xgboost\rabit\src
#     copying xgboost\rabit\src\allreduce_base.cc -> build\lib.win32-3.6\xgboost\rabit\src
#     copying xgboost\rabit\src\allreduce_base.h -> build\lib.win32-3.6\xgboost\rabit\src
#     copying xgboost\rabit\src\allreduce_mock.h -> build\lib.win32-3.6\xgboost\rabit\src
#     copying xgboost\rabit\src\engine.cc -> build\lib.win32-3.6\xgboost\rabit\src
#     copying xgboost\rabit\src\engine_mock.cc -> build\lib.win32-3.6\xgboost\rabit\src
#     copying xgboost\rabit\src\engine_mpi.cc -> build\lib.win32-3.6\xgboost\rabit\src
#     copying xgboost\rabit\src\rabit_c_api.cc -> build\lib.win32-3.6\xgboost\rabit\src
#     creating build\lib.win32-3.6\xgboost\src
#     copying xgboost\src\CMakeLists.txt -> build\lib.win32-3.6\xgboost\src
#     copying xgboost\src\cli_main.cc -> build\lib.win32-3.6\xgboost\src
#     copying xgboost\src\global_config.cc -> build\lib.win32-3.6\xgboost\src
#     copying xgboost\src\learner.cc -> build\lib.win32-3.6\xgboost\src
#     copying xgboost\src\logging.cc -> build\lib.win32-3.6\xgboost\src
#     creating build\lib.win32-3.6\xgboost\src\c_api
#     copying xgboost\src\c_api\c_api.cc -> build\lib.win32-3.6\xgboost\src\c_api
#     copying xgboost\src\c_api\c_api.cu -> build\lib.win32-3.6\xgboost\src\c_api
#     copying xgboost\src\c_api\c_api_error.cc -> build\lib.win32-3.6\xgboost\src\c_api
#     copying xgboost\src\c_api\c_api_error.h -> build\lib.win32-3.6\xgboost\src\c_api
#     copying xgboost\src\c_api\c_api_utils.h -> build\lib.win32-3.6\xgboost\src\c_api
#     creating build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\base64.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\bitfield.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\categorical.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\charconv.cc -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\charconv.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\column_matrix.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\common.cc -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\common.cu -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\common.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\compressed_iterator.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\config.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\device_helpers.cu -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\device_helpers.cuh -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\group_data.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\hist_util.cc -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\hist_util.cu -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\hist_util.cuh -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\hist_util.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\host_device_vector.cc -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\host_device_vector.cu -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\io.cc -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\io.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\json.cc -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\math.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\observer.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\partition_builder.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\probability_distribution.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\quantile.cc -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\quantile.cu -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\quantile.cuh -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\quantile.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\random.cc -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\random.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\ranking_utils.cuh -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\row_set.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\survival_util.cc -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\survival_util.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\threading_utils.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\timer.cc -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\timer.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\transform.h -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\version.cc -> build\lib.win32-3.6\xgboost\src\common
#     copying xgboost\src\common\version.h -> build\lib.win32-3.6\xgboost\src\common
#     creating build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\adapter.h -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\array_interface.cu -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\array_interface.h -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\data.cc -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\data.cu -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\device_adapter.cuh -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\ellpack_page.cc -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\ellpack_page.cu -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\ellpack_page.cuh -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\ellpack_page_raw_format.cu -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\ellpack_page_source.cu -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\ellpack_page_source.h -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\file_iterator.h -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\gradient_index.cc -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\gradient_index.h -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\gradient_index_format.cc -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\gradient_index_page_source.cc -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\gradient_index_page_source.h -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\histogram_cut_format.h -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\iterative_device_dmatrix.cu -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\iterative_device_dmatrix.h -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\proxy_dmatrix.cc -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\proxy_dmatrix.cu -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\proxy_dmatrix.cuh -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\proxy_dmatrix.h -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\simple_batch_iterator.h -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\simple_dmatrix.cc -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\simple_dmatrix.cu -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\simple_dmatrix.cuh -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\simple_dmatrix.h -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\sparse_page_dmatrix.cc -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\sparse_page_dmatrix.cu -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\sparse_page_dmatrix.h -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\sparse_page_raw_format.cc -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\sparse_page_source.cu -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\sparse_page_source.h -> build\lib.win32-3.6\xgboost\src\data
#     copying xgboost\src\data\sparse_page_writer.h -> build\lib.win32-3.6\xgboost\src\data
#     creating build\lib.win32-3.6\xgboost\src\gbm
#     copying xgboost\src\gbm\gblinear.cc -> build\lib.win32-3.6\xgboost\src\gbm
#     copying xgboost\src\gbm\gblinear_model.cc -> build\lib.win32-3.6\xgboost\src\gbm
#     copying xgboost\src\gbm\gblinear_model.h -> build\lib.win32-3.6\xgboost\src\gbm
#     copying xgboost\src\gbm\gbm.cc -> build\lib.win32-3.6\xgboost\src\gbm
#     copying xgboost\src\gbm\gbtree.cc -> build\lib.win32-3.6\xgboost\src\gbm
#     copying xgboost\src\gbm\gbtree.cu -> build\lib.win32-3.6\xgboost\src\gbm
#     copying xgboost\src\gbm\gbtree.h -> build\lib.win32-3.6\xgboost\src\gbm
#     copying xgboost\src\gbm\gbtree_model.cc -> build\lib.win32-3.6\xgboost\src\gbm
#     copying xgboost\src\gbm\gbtree_model.h -> build\lib.win32-3.6\xgboost\src\gbm
#     creating build\lib.win32-3.6\xgboost\src\linear
#     copying xgboost\src\linear\coordinate_common.h -> build\lib.win32-3.6\xgboost\src\linear
#     copying xgboost\src\linear\linear_updater.cc -> build\lib.win32-3.6\xgboost\src\linear
#     copying xgboost\src\linear\param.h -> build\lib.win32-3.6\xgboost\src\linear
#     copying xgboost\src\linear\updater_coordinate.cc -> build\lib.win32-3.6\xgboost\src\linear
#     copying xgboost\src\linear\updater_gpu_coordinate.cu -> build\lib.win32-3.6\xgboost\src\linear
#     copying xgboost\src\linear\updater_shotgun.cc -> build\lib.win32-3.6\xgboost\src\linear
#     creating build\lib.win32-3.6\xgboost\src\metric
#     copying xgboost\src\metric\auc.cc -> build\lib.win32-3.6\xgboost\src\metric
#     copying xgboost\src\metric\auc.cu -> build\lib.win32-3.6\xgboost\src\metric
#     copying xgboost\src\metric\auc.h -> build\lib.win32-3.6\xgboost\src\metric
#     copying xgboost\src\metric\elementwise_metric.cc -> build\lib.win32-3.6\xgboost\src\metric
#     copying xgboost\src\metric\elementwise_metric.cu -> build\lib.win32-3.6\xgboost\src\metric
#     copying xgboost\src\metric\metric.cc -> build\lib.win32-3.6\xgboost\src\metric
#     copying xgboost\src\metric\metric_common.h -> build\lib.win32-3.6\xgboost\src\metric
#     copying xgboost\src\metric\multiclass_metric.cc -> build\lib.win32-3.6\xgboost\src\metric
#     copying xgboost\src\metric\multiclass_metric.cu -> build\lib.win32-3.6\xgboost\src\metric
#     copying xgboost\src\metric\rank_metric.cc -> build\lib.win32-3.6\xgboost\src\metric
#     copying xgboost\src\metric\rank_metric.cu -> build\lib.win32-3.6\xgboost\src\metric
#     copying xgboost\src\metric\survival_metric.cc -> build\lib.win32-3.6\xgboost\src\metric
#     copying xgboost\src\metric\survival_metric.cu -> build\lib.win32-3.6\xgboost\src\metric
#     creating build\lib.win32-3.6\xgboost\src\objective
#     copying xgboost\src\objective\aft_obj.cc -> build\lib.win32-3.6\xgboost\src\objective
#     copying xgboost\src\objective\aft_obj.cu -> build\lib.win32-3.6\xgboost\src\objective
#     copying xgboost\src\objective\hinge.cc -> build\lib.win32-3.6\xgboost\src\objective
#     copying xgboost\src\objective\hinge.cu -> build\lib.win32-3.6\xgboost\src\objective
#     copying xgboost\src\objective\multiclass_obj.cc -> build\lib.win32-3.6\xgboost\src\objective
#     copying xgboost\src\objective\multiclass_obj.cu -> build\lib.win32-3.6\xgboost\src\objective
#     copying xgboost\src\objective\objective.cc -> build\lib.win32-3.6\xgboost\src\objective
#     copying xgboost\src\objective\rank_obj.cc -> build\lib.win32-3.6\xgboost\src\objective
#     copying xgboost\src\objective\rank_obj.cu -> build\lib.win32-3.6\xgboost\src\objective
#     copying xgboost\src\objective\regression_loss.h -> build\lib.win32-3.6\xgboost\src\objective
#     copying xgboost\src\objective\regression_obj.cc -> build\lib.win32-3.6\xgboost\src\objective
#     copying xgboost\src\objective\regression_obj.cu -> build\lib.win32-3.6\xgboost\src\objective
#     creating build\lib.win32-3.6\xgboost\src\predictor
#     copying xgboost\src\predictor\cpu_predictor.cc -> build\lib.win32-3.6\xgboost\src\predictor
#     copying xgboost\src\predictor\gpu_predictor.cu -> build\lib.win32-3.6\xgboost\src\predictor
#     copying xgboost\src\predictor\predict_fn.h -> build\lib.win32-3.6\xgboost\src\predictor
#     copying xgboost\src\predictor\predictor.cc -> build\lib.win32-3.6\xgboost\src\predictor
#     creating build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\constraints.cc -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\constraints.cu -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\constraints.cuh -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\constraints.h -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\driver.h -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\param.cc -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\param.h -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\split_evaluator.h -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\tree_model.cc -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\tree_updater.cc -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\updater_basemaker-inl.h -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\updater_colmaker.cc -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\updater_gpu_common.cuh -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\updater_gpu_hist.cu -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\updater_histmaker.cc -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\updater_prune.cc -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\updater_quantile_hist.cc -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\updater_quantile_hist.h -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\updater_refresh.cc -> build\lib.win32-3.6\xgboost\src\tree
#     copying xgboost\src\tree\updater_sync.cc -> build\lib.win32-3.6\xgboost\src\tree
#     creating build\lib.win32-3.6\xgboost\src\tree\gpu_hist
#     copying xgboost\src\tree\gpu_hist\evaluate_splits.cu -> build\lib.win32-3.6\xgboost\src\tree\gpu_hist
#     copying xgboost\src\tree\gpu_hist\evaluate_splits.cuh -> build\lib.win32-3.6\xgboost\src\tree\gpu_hist
#     copying xgboost\src\tree\gpu_hist\expand_entry.cuh -> build\lib.win32-3.6\xgboost\src\tree\gpu_hist
#     copying xgboost\src\tree\gpu_hist\feature_groups.cu -> build\lib.win32-3.6\xgboost\src\tree\gpu_hist
#     copying xgboost\src\tree\gpu_hist\feature_groups.cuh -> build\lib.win32-3.6\xgboost\src\tree\gpu_hist
#     copying xgboost\src\tree\gpu_hist\gradient_based_sampler.cu -> build\lib.win32-3.6\xgboost\src\tree\gpu_hist
#     copying xgboost\src\tree\gpu_hist\gradient_based_sampler.cuh -> build\lib.win32-3.6\xgboost\src\tree\gpu_hist
#     copying xgboost\src\tree\gpu_hist\histogram.cu -> build\lib.win32-3.6\xgboost\src\tree\gpu_hist
#     copying xgboost\src\tree\gpu_hist\histogram.cuh -> build\lib.win32-3.6\xgboost\src\tree\gpu_hist
#     copying xgboost\src\tree\gpu_hist\row_partitioner.cu -> build\lib.win32-3.6\xgboost\src\tree\gpu_hist
#     copying xgboost\src\tree\gpu_hist\row_partitioner.cuh -> build\lib.win32-3.6\xgboost\src\tree\gpu_hist
#     creating build\lib.win32-3.6\xgboost\src\tree\hist
#     copying xgboost\src\tree\hist\evaluate_splits.h -> build\lib.win32-3.6\xgboost\src\tree\hist
#     copying xgboost\src\tree\hist\histogram.h -> build\lib.win32-3.6\xgboost\src\tree\hist
#     running build_ext
#     creating build\temp.win32-3.6
#     creating build\temp.win32-3.6\Release
#     creating build\temp.win32-3.6\Release\xgboost
#     creating build\temp.win32-3.6\Release\xgboost\src
#     copying xgboost\src\cli_main.cc -> build\temp.win32-3.6\Release\xgboost\src
#     copying xgboost\src\CMakeLists.txt -> build\temp.win32-3.6\Release\xgboost\src
#     creating build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\base64.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\bitfield.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\categorical.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\charconv.cc -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\charconv.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\column_matrix.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\common.cc -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\common.cu -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\common.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\compressed_iterator.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\config.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\device_helpers.cu -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\device_helpers.cuh -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\group_data.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\hist_util.cc -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\hist_util.cu -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\hist_util.cuh -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\hist_util.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\host_device_vector.cc -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\host_device_vector.cu -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\io.cc -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\io.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\json.cc -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\math.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\observer.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\partition_builder.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\probability_distribution.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\quantile.cc -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\quantile.cu -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\quantile.cuh -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\quantile.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\random.cc -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\random.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\ranking_utils.cuh -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\row_set.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\survival_util.cc -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\survival_util.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\threading_utils.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\timer.cc -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\timer.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\transform.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\version.cc -> build\temp.win32-3.6\Release\xgboost\src\common
#     copying xgboost\src\common\version.h -> build\temp.win32-3.6\Release\xgboost\src\common
#     creating build\temp.win32-3.6\Release\xgboost\src\c_api
#     copying xgboost\src\c_api\c_api.cc -> build\temp.win32-3.6\Release\xgboost\src\c_api
#     copying xgboost\src\c_api\c_api.cu -> build\temp.win32-3.6\Release\xgboost\src\c_api
#     copying xgboost\src\c_api\c_api_error.cc -> build\temp.win32-3.6\Release\xgboost\src\c_api
#     copying xgboost\src\c_api\c_api_error.h -> build\temp.win32-3.6\Release\xgboost\src\c_api
#     copying xgboost\src\c_api\c_api_utils.h -> build\temp.win32-3.6\Release\xgboost\src\c_api
#     creating build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\adapter.h -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\array_interface.cu -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\array_interface.h -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\data.cc -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\data.cu -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\device_adapter.cuh -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\ellpack_page.cc -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\ellpack_page.cu -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\ellpack_page.cuh -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\ellpack_page_raw_format.cu -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\ellpack_page_source.cu -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\ellpack_page_source.h -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\file_iterator.h -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\gradient_index.cc -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\gradient_index.h -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\gradient_index_format.cc -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\gradient_index_page_source.cc -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\gradient_index_page_source.h -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\histogram_cut_format.h -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\iterative_device_dmatrix.cu -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\iterative_device_dmatrix.h -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\proxy_dmatrix.cc -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\proxy_dmatrix.cu -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\proxy_dmatrix.cuh -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\proxy_dmatrix.h -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\simple_batch_iterator.h -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\simple_dmatrix.cc -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\simple_dmatrix.cu -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\simple_dmatrix.cuh -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\simple_dmatrix.h -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\sparse_page_dmatrix.cc -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\sparse_page_dmatrix.cu -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\sparse_page_dmatrix.h -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\sparse_page_raw_format.cc -> build\temp.win32-3.6\Release\xgboost\src\data
#     copying xgboost\src\data\sparse_page_source.cu -> build\temp.win32-3.6\Release\xgboost\src\data
# ...
#     copying xgboost\dmlc-core\include\dmlc\strtonum.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\threadediter.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\thread_group.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\thread_local.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\timer.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\include\dmlc
#     copying xgboost\dmlc-core\include\dmlc\type_traits.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\include\dmlc
#     creating build\temp.win32-3.6\Release\xgboost\dmlc-core\make
#     copying xgboost\dmlc-core\make\config.mk -> build\temp.win32-3.6\Release\xgboost\dmlc-core\make
#     copying xgboost\dmlc-core\make\dmlc.mk -> build\temp.win32-3.6\Release\xgboost\dmlc-core\make
#     creating build\temp.win32-3.6\Release\xgboost\dmlc-core\src
#     copying xgboost\dmlc-core\src\config.cc -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src
#     creating build\temp.win32-3.6\Release\xgboost\dmlc-core\src\data
#     copying xgboost\dmlc-core\src\data\basic_row_iter.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\data
#     copying xgboost\dmlc-core\src\data\csv_parser.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\data
#     copying xgboost\dmlc-core\src\data\disk_row_iter.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\data
#     copying xgboost\dmlc-core\src\data\libfm_parser.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\data
#     copying xgboost\dmlc-core\src\data\libsvm_parser.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\data
#     copying xgboost\dmlc-core\src\data\parser.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\data
#     copying xgboost\dmlc-core\src\data\row_block.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\data
#     copying xgboost\dmlc-core\src\data\text_parser.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\data
#     copying xgboost\dmlc-core\src\data.cc -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src
#     creating build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\azure_filesys.cc -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\azure_filesys.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\cached_input_split.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\filesys.cc -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\hdfs_filesys.cc -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\hdfs_filesys.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\indexed_recordio_split.cc -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\indexed_recordio_split.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\input_split_base.cc -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\input_split_base.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\line_split.cc -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\line_split.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\local_filesys.cc -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\local_filesys.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\recordio_split.cc -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\recordio_split.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\s3_filesys.cc -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\s3_filesys.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\single_file_split.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\single_threaded_input_split.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\threaded_input_split.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io\uri_spec.h -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src\io
#     copying xgboost\dmlc-core\src\io.cc -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src
#     copying xgboost\dmlc-core\src\recordio.cc -> build\temp.win32-3.6\Release\xgboost\dmlc-core\src
#     creating build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker
#     copying xgboost\dmlc-core\tracker\dmlc-submit -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker
#     creating build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\kubernetes.py -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\launcher.py -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\local.py -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\mesos.py -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\mpi.py -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\opts.py -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\sge.py -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\slurm.py -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\ssh.py -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\submit.py -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\tracker.py -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\util.py -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\yarn.py -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\dmlc_tracker
#     copying xgboost\dmlc-core\tracker\dmlc_tracker\__init__.py -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\dmlc_tracker
#     creating build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\yarn
#     copying xgboost\dmlc-core\tracker\yarn\build.bat -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\yarn
#     copying xgboost\dmlc-core\tracker\yarn\build.sh -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\yarn
#     copying xgboost\dmlc-core\tracker\yarn\pom.xml -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\yarn
#     creating build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\yarn\src
#     creating build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\yarn\src\main
#     creating build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\yarn\src\main\java
#     creating build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\yarn\src\main\java\org
#     creating build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache
#     creating build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop
#     creating build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop\yarn
#     creating build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop\yarn\dmlc
#     copying xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop\yarn\dmlc\ApplicationMaster.java -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop\yarn\dmlc
#     copying xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop\yarn\dmlc\Client.java -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop\yarn\dmlc
#     copying xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop\yarn\dmlc\TaskRecord.java -> build\temp.win32-3.6\Release\xgboost\dmlc-core\tracker\yarn\src\main\java\org\apache\hadoop\yarn\dmlc
#     creating build\temp.win32-3.6\Release\xgboost\dmlc-core\windows
#     creating build\temp.win32-3.6\Release\xgboost\dmlc-core\windows\dmlc
#     copying xgboost\dmlc-core\windows\dmlc\dmlc.vcxproj -> build\temp.win32-3.6\Release\xgboost\dmlc-core\windows\dmlc
#     copying xgboost\dmlc-core\windows\dmlc.sln -> build\temp.win32-3.6\Release\xgboost\dmlc-core\windows
#     creating build\temp.win32-3.6\Release\xgboost\rabit
#     copying xgboost\rabit\CMakeLists.txt -> build\temp.win32-3.6\Release\xgboost\rabit
#     creating build\temp.win32-3.6\Release\xgboost\rabit\include
#     creating build\temp.win32-3.6\Release\xgboost\rabit\include\rabit
#     copying xgboost\rabit\include\rabit\base.h -> build\temp.win32-3.6\Release\xgboost\rabit\include\rabit
#     copying xgboost\rabit\include\rabit\c_api.h -> build\temp.win32-3.6\Release\xgboost\rabit\include\rabit
#     creating build\temp.win32-3.6\Release\xgboost\rabit\include\rabit\internal
#     copying xgboost\rabit\include\rabit\internal\engine.h -> build\temp.win32-3.6\Release\xgboost\rabit\include\rabit\internal
#     copying xgboost\rabit\include\rabit\internal\io.h -> build\temp.win32-3.6\Release\xgboost\rabit\include\rabit\internal
#     copying xgboost\rabit\include\rabit\internal\rabit-inl.h -> build\temp.win32-3.6\Release\xgboost\rabit\include\rabit\internal
#     copying xgboost\rabit\include\rabit\internal\socket.h -> build\temp.win32-3.6\Release\xgboost\rabit\include\rabit\internal
#     copying xgboost\rabit\include\rabit\internal\utils.h -> build\temp.win32-3.6\Release\xgboost\rabit\include\rabit\internal
#     copying xgboost\rabit\include\rabit\rabit.h -> build\temp.win32-3.6\Release\xgboost\rabit\include\rabit
#     copying xgboost\rabit\include\rabit\serializable.h -> build\temp.win32-3.6\Release\xgboost\rabit\include\rabit
#     creating build\temp.win32-3.6\Release\xgboost\rabit\src
#     copying xgboost\rabit\src\allreduce_base.cc -> build\temp.win32-3.6\Release\xgboost\rabit\src
#     copying xgboost\rabit\src\allreduce_base.h -> build\temp.win32-3.6\Release\xgboost\rabit\src
#     copying xgboost\rabit\src\allreduce_mock.h -> build\temp.win32-3.6\Release\xgboost\rabit\src
#     copying xgboost\rabit\src\engine.cc -> build\temp.win32-3.6\Release\xgboost\rabit\src
#     copying xgboost\rabit\src\engine_mock.cc -> build\temp.win32-3.6\Release\xgboost\rabit\src
#     copying xgboost\rabit\src\engine_mpi.cc -> build\temp.win32-3.6\Release\xgboost\rabit\src
#     copying xgboost\rabit\src\rabit_c_api.cc -> build\temp.win32-3.6\Release\xgboost\rabit\src
#     creating build\temp.win32-3.6\Release\xgboost\cmake
#     copying xgboost\cmake\Doc.cmake -> build\temp.win32-3.6\Release\xgboost\cmake
#     copying xgboost\cmake\FindPrefetchIntrinsics.cmake -> build\temp.win32-3.6\Release\xgboost\cmake
#     creating build\temp.win32-3.6\Release\xgboost\cmake\modules
#     copying xgboost\cmake\modules\FindNccl.cmake -> build\temp.win32-3.6\Release\xgboost\cmake\modules
#     copying xgboost\cmake\modules\FindNVML.cmake -> build\temp.win32-3.6\Release\xgboost\cmake\modules
#     copying xgboost\cmake\modules\FindNVTX.cmake -> build\temp.win32-3.6\Release\xgboost\cmake\modules
#     copying xgboost\cmake\Python_version.in -> build\temp.win32-3.6\Release\xgboost\cmake
#     copying xgboost\cmake\Utils.cmake -> build\temp.win32-3.6\Release\xgboost\cmake
#     copying xgboost\cmake\Version.cmake -> build\temp.win32-3.6\Release\xgboost\cmake
#     copying xgboost\cmake\version_config.h.in -> build\temp.win32-3.6\Release\xgboost\cmake
#     copying xgboost\cmake\xgboost-config.cmake.in -> build\temp.win32-3.6\Release\xgboost\cmake
#     copying xgboost\cmake\xgboost.pc.in -> build\temp.win32-3.6\Release\xgboost\cmake
#     creating build\temp.win32-3.6\Release\xgboost\plugin
#     copying xgboost\plugin\CMakeLists.txt -> build\temp.win32-3.6\Release\xgboost\plugin
#     creating build\temp.win32-3.6\Release\xgboost\plugin\dense_parser
#     copying xgboost\plugin\dense_parser\dense_libsvm.cc -> build\temp.win32-3.6\Release\xgboost\plugin\dense_parser
#     creating build\temp.win32-3.6\Release\xgboost\plugin\example
#     copying xgboost\plugin\example\custom_obj.cc -> build\temp.win32-3.6\Release\xgboost\plugin\example
#     copying xgboost\plugin\example\README.md -> build\temp.win32-3.6\Release\xgboost\plugin\example
#     copying xgboost\plugin\README.md -> build\temp.win32-3.6\Release\xgboost\plugin
#     creating build\temp.win32-3.6\Release\xgboost\plugin\updater_gpu
#     copying xgboost\plugin\updater_gpu\README.md -> build\temp.win32-3.6\Release\xgboost\plugin\updater_gpu
#     creating build\temp.win32-3.6\Release\xgboost\plugin\updater_oneapi
#     copying xgboost\plugin\updater_oneapi\predictor_oneapi.cc -> build\temp.win32-3.6\Release\xgboost\plugin\updater_oneapi
#     copying xgboost\plugin\updater_oneapi\README.md -> build\temp.win32-3.6\Release\xgboost\plugin\updater_oneapi
#     copying xgboost\plugin\updater_oneapi\regression_loss_oneapi.h -> build\temp.win32-3.6\Release\xgboost\plugin\updater_oneapi
#     copying xgboost\plugin\updater_oneapi\regression_obj_oneapi.cc -> build\temp.win32-3.6\Release\xgboost\plugin\updater_oneapi
#     copying xgboost\CMakeLists.txt -> build\temp.win32-3.6\Release\xgboost
#     copying xgboost\LICENSE -> build\temp.win32-3.6\Release\xgboost
#     INFO:XGBoost build_ext:Building from source. C:\Users\jaxon\AppData\Local\Temp\pip-install-yuncal1r\lib\xgboost.dll
#     INFO:XGBoost build_ext:Run CMake command: ['cmake', 'xgboost', '-GVisual Studio 16 2019', '-DUSE_OPENMP=1', '-DUSE_CUDA=0', '-DUSE_NCCL=0', '-DBUILD_WITH_SHARED_NCCL=0', '-DHIDE_CXX_SYMBOLS=1', '-DUSE_HDFS=0', '-DUSE_AZURE=0', '-DUSE_S3=0', '-DPLUGIN_DENSE_PARSER=0']
#     error: [WinError 2] The system cannot find the file specified
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'c:\users\jaxon\appdata\local\programs\python\python36-32\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jaxon\\AppData\\Local\\Temp\\pip-install-yuncal1r\\xgboost_b01f77f0d38a450da1c0db361f4f4dbd\\setup.py'"'"'; __file__='"'"'C:\\Users\\jaxon\\AppData\\Local\\Temp\\pip-install-yuncal1r\\xgboost_b01f77f0d38a450da1c0db361f4f4dbd\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\jaxon\AppData\Local\Temp\pip-record-zk479j1o\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\users\jaxon\appdata\local\programs\python\python36-32\Include\xgboost' Check the logs for full command output.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 11
#       9 from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
#      10 from sklearn.tree import DecisionTreeRegressor
# ---> 11 import xgboost as xgb
#      12 from lightgbm import LGBMRegressor
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
len(df)
# Out:
# 205

# %%
lasso_reg = Lasso(alpha=0.005)
lasso_reg.fit(X_train, y_train)
Y_pred = lasso_reg.predict(X_test)

# %%
df.columns
# Out:
# Index(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
#        'fuelsystem', 'boreratio', 'horsepower', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', 500)

# %%
cols = ['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
       'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth',
       'carheight', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
       'fuelsystem', 'boreratio', 'horsepower', 'citympg', 'highwaympg']
new_data = ['nissan', 'petrol', 'std', 'four', 'sedan', 'rwd', 'front', 85, 168.8, 64.1, 50, 2824, 'dohc', 'four', 130, 'mpfi', 3, 100, 17, 26]
print(len(cols)==len(new_data))

#Check if string data is catgorical
ind = []
for i in range(len(new_data)): 
    if type(new_data[i]) ==  str: 
        ind.append(cols[i]) 

print(ind == categorical)
# Out:
# True
# True

# %%
#Transform new input
new_data_df = pd.DataFrame([new_data],columns = cols)

# %%
#Transform data to fit model
def transform(data):
    #Columns of the df
    cols = ['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
       'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth',
       'carheight', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
       'fuelsystem', 'boreratio', 'horsepower', 'citympg', 'highwaympg']

    new_df = pd.DataFrame([data],columns = cols)
    #print(new_df)

    cat = []
    num = []
    for col in new_df.columns: 
        if new_df[col].dtypes == 'object': 
            cat.append(col)
        else: 
            num.append(col)
    #print(cat)
    #print(num)
    x1_new = pd.get_dummies(new_df[cat], drop_first = False)
    #print(x1_new)
    x2_new = new_df[num]
    #print(x2_new)
    X_new = pd.concat([x2_new,x1_new], axis = 1)
    #print(X_new)

    final_df = pd.DataFrame(columns = cols_to_use)
    final_df = pd.concat([final_df, X_new])
    final_df = final_df.fillna(0)
    #print(final_df)

    X_new = final_df.values
    #print(X_new)
    
    
    X_new[:, :(len(x1.columns))]= sc.transform(X_new[:, :(len(x1.columns))])

    output = lasso_reg.predict(X_new)
    print(np.exp(output))

    
new_data = ['volkswagen', 'gas', 'std', 'four', 'sedan', 'rwd', 'front', 80, 150, 64.1, 50, 1500, 'dohc', 'four', 130, 'mpfi', 3, 150, 17, 26]
transform(new_data)
# Out:
# [8954.06541768]

# %%
df.head()
#sns.countplot(data=df, x='fueltype')
df.groupby('enginelocation').count()
# Out:
#                 CarName  fueltype  aspiration  doornumber  carbody  \
# enginelocation
# front               202       202         202         202      202
# rear                  3         3           3           3        3
#
#                 drivewheel  wheelbase  carlength  carwidth  carheight  \
# enginelocation
# front                  202        202        202       202        202
# rear                     3          3          3         3          3
#
#                 curbweight  enginetype  cylindernumber  enginesize  \
# enginelocation
# front                  202         202             202         202
# rear                     3           3               3           3
#
#                 fuelsystem  boreratio  horsepower  citympg  highwaympg  price
# enginelocation
# front                  202        202         202      202         202    202
# rear                     3          3           3        3           3      3

# %%
pickle.dump(lasso_reg, open('model.pkl','wb'))

# %%
df.CarName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
df.head()
# Out:
#        CarName fueltype aspiration doornumber      carbody drivewheel  \
# 0  alfa-romero      gas        std        two  convertible        rwd
# 1  alfa-romero      gas        std        two  convertible        rwd
# 2  alfa-romero      gas        std        two    hatchback        rwd
# 3         audi      gas        std       four        sedan        fwd
# 4         audi      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          front       88.6      168.8      64.1       48.8        2548
# 1          front       88.6      168.8      64.1       48.8        2548
# 2          front       94.5      171.2      65.5       52.4        2823
# 3          front       99.8      176.6      66.2       54.3        2337
# 4          front       99.4      176.6      66.4       54.3        2824
#
#   enginetype cylindernumber  enginesize fuelsystem  boreratio  horsepower  \
# 0       dohc           four         130       mpfi       3.47         111
# 1       dohc           four         130       mpfi       3.47         111
# 2       ohcv            six         152       mpfi       2.68         154
# 3        ohc           four         109       mpfi       3.19         102
# 4        ohc           five         136       mpfi       3.19         115
#
#    citympg  highwaympg    price
# 0       21          27  13495.0
# 1       21          27  16500.0
# 2       19          26  16500.0
# 3       24          30  13950.0
# 4       18          22  17450.0

# %%
df.cylindernumber.unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
sns.countplot(data = df, x = 'enginetype')
# Out:
# <AxesSubplot:xlabel='enginetype', ylabel='count'>

# %%
cols_to_use
# Out:
# Index(['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'enginesize', 'boreratio', 'horsepower', 'citympg', 'highwaympg',
#        'CarName_alfa-romero', 'CarName_audi', 'CarName_bmw', 'CarName_buick',
#        'CarName_chevrolet', 'CarName_dodge', 'CarName_honda', 'CarName_isuzu',
#        'CarName_jaguar', 'CarName_mazda', 'CarName_mercury',
#        'CarName_mitsubishi', 'CarName_nissan', 'CarName_peugeot',
#        'CarName_plymouth', 'CarName_porsche', 'CarName_renault',
#        'CarName_saab', 'CarName_subaru', 'CarName_toyota',
#        'CarName_volkswagen', 'CarName_volvo', 'fueltype_diesel',
#        'fueltype_gas', 'aspiration_std', 'aspiration_turbo', 'doornumber_four',
#        'doornumber_two', 'carbody_convertible', 'carbody_hardtop',
#        'carbody_hatchback', 'carbody_sedan', 'carbody_wagon', 'drivewheel_4wd',
#        'drivewheel_fwd', 'drivewheel_rwd', 'enginelocation_front',
#        'enginelocation_rear', 'enginetype_dohc', 'enginetype_dohcv',
#        'enginetype_l', 'enginetype_ohc', 'enginetype_ohcf', 'enginetype_ohcv',
#        'enginetype_rotor', 'cylindernumber_eight', 'cylindernumber_five',
#        'cylindernumber_four', 'cylindernumber_six', 'cylindernumber_three',
#        'cylindernumber_twelve', 'cylindernumber_two', 'fuelsystem_1bbl',
#        'fuelsystem_2bbl', 'fuelsystem_4bbl', 'fuelsystem_idi',
#        'fuelsystem_mfi', 'fuelsystem_mpfi', 'fuelsystem_spdi',
#        'fuelsystem_spfi'],
#       dtype='object')

# %%
df.to_csv('df_columns')

# %%
#Make first pred and grid search with 4 models: 
models = {
    "rfr":RandomForestRegressor(n_estimators=3000, max_depth=10),
    "lasso":Lasso(alpha=0.005), 
    "ridge":Ridge(alpha=0.005), 
    "xgb":xgb.XGBRegressor(n_estimators=4000, max_depth=10, random_state=43)    
}

res_r2 = []
res_RMSE = []
res_MAE = []
def metrics(model): 
    model.fit(X_train, y_train)
    Y_pred = model.predict(X_test)
        
    #Compute r squared
    r2 = round(r2_score(y_test, Y_pred),4)
    print( 'R2_Score: ', r2)
    res_r2.append(r2)

    #Compute root mean squared error
    rmse = round(mean_squared_error(np.exp(y_test),np.exp(Y_pred), squared=False), 2)
    print("RMSE: ",rmse)
    res_RMSE.append(rmse)
        
    #Compute mean squared error
    mse = round(mean_absolute_error(np.exp(y_test),np.exp(Y_pred)), 2)
    print("MAE: ", mse)
    res_MAE.append(mse)


for mod in models: 
    if mod == 'rfr' or mod == 'xgb':
        print('Untuned metrics for: ', mod)
        metrics(models[mod])
        print('\n')
        print('Starting grid search for: ', mod)
        params = { 
            "n_estimators"      : [10,100, 1000, 2000, 4000, 6000],
            "max_features"      : ["auto", "sqrt", "log2"],
            "max_depth"         : [2, 4, 8, 12, 15],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }
        if mod == 'rfr': 
            rfr = RandomForestRegressor()
            grid = GridSearchCV(rfr, params, verbose=5, cv=2)
            grid.fit(X_train, y_train)
            print("Best score: ", grid.best_score_ )
            print("Best: params", grid.best_params_)
        else: 
            xgboost = xgb.XGBRegressor()
            grid = GridSearchCV(xgboost, params, verbose=5, cv=2)
            grid.fit(X_train, y_train)
            print("Best score: ", grid.best_score_ )
            print("Best: params", grid.best_params_)
    else: 
        print('Untuned metrics for: ', mod)
        metrics(models[mod])
        print('\n')
        print('Starting grid search for: ', mod)
        params = {
              "alpha": [0.005, 0.05, 0.1, 1, 10, 100, 290, 500],
              "fit_intercept": [True, False]
            }
        if mod == 'lasso': 
            lasso = Lasso()
            grid = GridSearchCV(lasso, params, verbose = 5, cv = 2)
            grid.fit(X_train, y_train)
            print("Best score: ", grid.best_score_ )
            print("Best: params", grid.best_params_)
        else: 
            ridge = Ridge()
            grid = GridSearchCV(ridge, params, verbose = 5, cv = 2)
            grid.fit(X_train, y_train)
            print("Best score: ", grid.best_score_ )
            print("Best: params", grid.best_params_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #Make first pred and grid search with 4 models:
#       2 models = {
# ----> 3     "rfr":RandomForestRegressor(n_estimators=3000, max_depth=10),
#       4     "lasso":Lasso(alpha=0.005),
#       5     "ridge":Ridge(alpha=0.005),
#       6     "xgb":xgb.XGBRegressor(n_estimators=4000, max_depth=10, random_state=43)
#       7 }
#       9 res_r2 = []
#      10 res_RMSE = []
#
# NameError: name 'RandomForestRegressor' is not defined

# %%
#Models with tuned parameters
models={
    'rfr':RandomForestRegressor(bootstrap=False, max_depth=15, max_features='sqrt', min_samples_split=2, n_estimators=100),
    'lasso':Lasso(alpha=0.005, fit_intercept=True),
    'ridge':Ridge(alpha = 10, fit_intercept=True),
    'xgb':xgb.XGBRegressor(bootstrap=True, max_depth=2, max_features = 'auto', min_sample_split = 2, n_estimators = 100)
}

def metrics(model): 
    model.fit(X_train, y_train)
    Y_pred = model.predict(X_test)
        
    #Compute r squared
    r2 = round(r2_score(y_test, Y_pred),4)
    print( 'R2_Score: ', r2)
    res_r2.append(r2)

    #Compute root mean squared error
    rmse = round(mean_squared_error(np.exp(y_test),np.exp(Y_pred), squared=False), 2)
    print("RMSE: ",rmse)
    res_RMSE.append(rmse)
        
    #Compute mean squared error
    mse = round(mean_absolute_error(np.exp(y_test),np.exp(Y_pred)), 2)
    print("MAE: ", mse)
    res_MAE.append(mse)

for mod in models:
    print(mod)
    metrics(models[mod])
    print('\n')
# Out:
# rfr
# R2_Score:  0.9198
# RMSE:  2121.07
# MAE:  1333.09
#
#
# lasso
# R2_Score:  0.9305
# RMSE:  1767.75
# MAE:  1195.47
#
#
# ridge
# R2_Score:  0.9261
# RMSE:  2115.54
# MAE:  1370.68
#
#
# xgb
# [11:48:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "bootstrap", "max_features", "min_sample_split" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# R2_Score:  0.9276
# RMSE:  2182.05
# MAE:  1460.99
